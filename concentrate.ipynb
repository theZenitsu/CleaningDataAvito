# %%
import pandas as pd

# %%
df = pd.read_csv('/home/corolo/Desktop/analysisAvito/data/appartements_data.csv')

# %%
just_copy = df.copy()

# %%
df
# Out:
#                                                   title         price  \
# 0             Appartement location de vacances à Meknès  300 DH /Nuit
# 1                                   appartement à louer      2 400 DH
# 2              Appartement beru à louer 150 m² à Temara      6 500 DH
# 3          Appartement près a casanearshor sidi maarouf      3 000 DH
# 4       Appartement 84 m²Al Baraka à Dcheïra El Jihadia    701 720 DH
# ...                                                 ...           ...
# 1058  Appartement de 151m² en centre de Tanger à vendre  1 850 000 DH
# 1059             Appartement à louer 90 m² à Casablanca     12 500 DH
# 1060                        Bel Appartement Cœur Gueliz  2 900 000 DH
# 1061                        appartement à vendre ouilfa    990 000 DH
# 1062             Appartement à vendre 85 m² à Marrakech  1 200 000 DH
#
#                 location           type_de_vente  salon  chamber  toilete  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1063 entries, 0 to 1062
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1062 non-null   object
#  1   price          930 non-null    object
#  2   location       1062 non-null   object
#  3   type_de_vente  386 non-null    object
#  4   salon          640 non-null    float64
#  5   chamber        339 non-null    float64
#  6   toilete        336 non-null    float64
#  7   area           693 non-null    float64
#  8   link           1063 non-null   object
# dtypes: float64(4), object(5)
# memory usage: 74.9+ KB

# %%
df.loc[1:10]
# Out:
#                                                 title         price  \
# 1                                 appartement à louer      2 400 DH
# 2            Appartement beru à louer 150 m² à Temara      6 500 DH
# 3        Appartement près a casanearshor sidi maarouf      3 000 DH
# 4     Appartement 84 m²Al Baraka à Dcheïra El Jihadia    701 720 DH
# 5             Appartement à vendre 79 m² à Casablanca    580 000 DH
# 6                 Appartement 3 chambres vide à louer      6 800 DH
# 7        Appart. 79 m2 Angle Chouka Omarya-Hay Chrifa    760 000 DH
# 8           Appartement location de vacances à Agadir           NaN
# 9   Appart. Haut Stand 104 m2 Résid. Fermée Califo...  1 560 000 DH
# 10             CMN-MA-1136 - Bureau à vendre à Maârif  1 100 000 DH
#
#               location           type_de_vente  salon  chamber  toilete  \
# 1           Casablanca                     NaN    1.0      NaN      NaN
# 2               Temara                     NaN    1.0      NaN      NaN
# ...

# %%
df.iloc[1:10]
# Out:
#                                                title         price  \
# 1                                appartement à louer      2 400 DH
# 2           Appartement beru à louer 150 m² à Temara      6 500 DH
# 3       Appartement près a casanearshor sidi maarouf      3 000 DH
# 4    Appartement 84 m²Al Baraka à Dcheïra El Jihadia    701 720 DH
# 5            Appartement à vendre 79 m² à Casablanca    580 000 DH
# 6                Appartement 3 chambres vide à louer      6 800 DH
# 7       Appart. 79 m2 Angle Chouka Omarya-Hay Chrifa    760 000 DH
# 8          Appartement location de vacances à Agadir           NaN
# 9  Appart. Haut Stand 104 m2 Résid. Fermée Califo...  1 560 000 DH
#
#              location           type_de_vente  salon  chamber  toilete   area  \
# 1          Casablanca                     NaN    1.0      NaN      NaN   50.0
# 2              Temara                     NaN    1.0      NaN      NaN  150.0
# ...

# %%
df.columns
# Out:
# Index(['title', 'price', 'location', 'type_de_vente', 'salon', 'chamber',
#        'toilete', 'area', 'link'],
#       dtype='object')

# %%
df.dtypes
# Out:
# title             object
# price             object
# location          object
# type_de_vente     object
# salon            float64
# chamber          float64
# toilete          float64
# area             float64
# link              object
# dtype: object

# %%
df.describe()
# Out:
#             salon     chamber     toilete        area
# count  640.000000  339.000000  336.000000  693.000000
# mean     1.223437    2.368732    2.401786   97.308802
# std      0.452862    0.668188    7.893840   40.543845
# min      0.000000    1.000000    0.000000    1.000000
# 25%      1.000000    2.000000    1.000000   70.000000
# 50%      1.000000    2.000000    2.000000   90.000000
# 75%      1.000000    3.000000    2.000000  115.000000
# max      3.000000    6.000000  100.000000  500.000000

# %%
df.head(10)
# Out:
#                                                title         price  \
# 0          Appartement location de vacances à Meknès  300 DH /Nuit
# 1                                appartement à louer      2 400 DH
# 2           Appartement beru à louer 150 m² à Temara      6 500 DH
# 3       Appartement près a casanearshor sidi maarouf      3 000 DH
# 4    Appartement 84 m²Al Baraka à Dcheïra El Jihadia    701 720 DH
# 5            Appartement à vendre 79 m² à Casablanca    580 000 DH
# 6                Appartement 3 chambres vide à louer      6 800 DH
# 7       Appart. 79 m2 Angle Chouka Omarya-Hay Chrifa    760 000 DH
# 8          Appartement location de vacances à Agadir           NaN
# 9  Appart. Haut Stand 104 m2 Résid. Fermée Califo...  1 560 000 DH
#
#              location           type_de_vente  salon  chamber  toilete   area  \
# 0              Meknès                     NaN    NaN      NaN      NaN    NaN
# ...

# %%
df.loc[df.duplicated()]
# Out:
#                                                  title         price  \
# 319         Appartement à louer pour vacances . LDV481           NaN
# 320                       Appartement à louer à Nasime      2 500 DH
# 712  Appartement de vacances – Proche de la Gare Agdal  950 DH /Nuit
# 884  App avec ascenseur et WiFi, proche de la mer anza  300 DH /Nuit
# 922                    Appartement économique à vendre    190 000 DH
#
#        location           type_de_vente  salon  chamber  toilete  area  \
# 319      Agadir                     NaN    NaN      NaN      NaN   NaN
# 320  Mohammedia                     NaN    1.0      NaN      NaN  60.0
# 712       Rabat                     NaN    NaN      NaN      NaN   NaN
# 884      Agadir                     NaN    NaN      NaN      NaN   NaN
# 922        Salé  Appartements, à vendre    1.0      2.0      1.0  55.0
#
#                                      link
# 319  https://www.avito.ma/vi/54273681.htm
# ...
